# %% [markdown]
# <img src="./images/book.jpeg" alt="drawing" width="300" align="left"/>
# <img src="./images/NigelPoulton.jpg" alt="drawing" width="314" align="left"/>

# %% [markdown]
# **[Docker Deep Dive: Zero to Docker in a single book](https://www.amazon.com/gp/product/B01LXWQUFF/ref=dbs_a_def_rwt_bibl_vppi_i1)**

# %% [markdown]
# #  intro to container
# ## Virtualization
#
# - **HW-Level Virtualization**
#     - **Network Virtualization**
#     - **Storage Virtualization**
#     - **Server  Virtualization**
# - **Application Virtualization**
# - **OS-Level Virtualization**
#
# ![image-2.png](attachment:image-2.png)
#
# the problem here appear cause the the resources of VM be consumed on OS,licences of OS for every VM instead of the target app:
#
# ![image.png](attachment:image.png)
# ![image-4.png](attachment:image-4.png)
#
# there is another teecnique for VM. using template:-
#
# ![image-3.png](attachment:image-3.png)
#
#     The question is can we solve these issue :-
#
# ## Container
#
# we have os in kernal mode and user mode, so we need to separate the user mode and use only kernal mode for the host machine "shared for all app".
# so in Container, we use kernal mode for the host machine shared for all app and we will not use full OS which is installed for every VM.
# so this will help us and increase efficiency cause the security and devops will be maked a once for the kernal mode shared
#
# ![image-5.png](attachment:image-5.png)
#
#
# ### Container Arch
#
# 1- in VM,
#
# ![image-6.png](attachment:image-6.png)
#
# .VHD ----> base desk
# .AHD ----> differential desk
#
# ![image-7.png](attachment:image-7.png)
#
#
# 1- in Container,
#
# to be noted that the kernal for every OS is once for example on ubuntu use the kernal of linux then add some features
# OS spec ------> user mode
#
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
# ![image-11.png](attachment:image-11.png)
#
#
#     - in VM         ---> base desk and diff desk
#       in container  ---> layers
#
# ![image-8.png](attachment:image-8.png)
# ![image-12.png](attachment:image-12.png)
#
#     - image it is the container image like VM template
#
# ![image-13.png](attachment:image-13.png)
# ![image-14.png](attachment:image-14.png)
# ![image-15.png](attachment:image-15.png)
#
#     - linux sys depen on container scine 50 years but internal container "cgroups, namespcaes" to monitor the resouces
#         cgourps ---> to monitor the resoucrces for the process
#         namespaces ---> to monitor the herirhery of the parent and child and ensure all the process see the resources
#
# ![image-16.png](attachment:image-16.png)
# ![image-17.png](attachment:image-17.png)
#
#      the same in container we have process runc layer which called os layer whch called python layer
#
# ![image-18.png](attachment:image-18.png)
#
#
#
#     - there are tecnologies for apply VM        ----> VM ware
#       there are tecnologies for apply container ----> Docker

# %% [markdown]
# # Docker
#
# Docker is a software platform that allows you to build, test, and deploy applications quickly. Docker packages software into standardized units called containers that have everything the software needs to run including libraries, system tools, code, and runtime.
#
# types of container ----->  win kernal or linux kernal
# software itself    ----->  win, linux, mac. ----> so if we used container in mac it will be win or linux container ??? Docker desktop for mac
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
